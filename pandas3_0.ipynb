# %% [markdown]
# <a href="https://colab.research.google.com/github/adityachava2022/collabnotes/blob/master/pandas3_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #concatenation

# %%
users = pd.DataFrame({'userid':[1,2,3],'name':['vinayak','mayank','aravind']})
users
# Out:
#    userid     name
# 0       1  vinayak
# 1       2   mayank
# 2       3  aravind

# %%
users1 = pd.DataFrame({'userid':[1,2,3,'4'],'name':['vinayak','mayank','aravind','abc']})
users1
# Out:
#   userid     name
# 0      1  vinayak
# 1      2   mayank
# 2      3  aravind
# 3      4      abc

# %%
type(users1.loc[2]['userid'])
# Out:
# int

# %%
type(users1.loc[3]['userid'])
# Out:
# str

# %%
users1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   userid  4 non-null      object
#  1   name    4 non-null      object
# dtypes: object(2)
# memory usage: 196.0+ bytes

# %%
msgs = pd.DataFrame({'userid':[1,1,2,4],'msg':['hmm','ohk','haha','thik hai']})
msgs
# Out:
#    userid       msg
# 0       1       hmm
# 1       1       ohk
# 2       2      haha
# 3       4  thik hai

# %%
pd.concat([users,msgs]) #default axis=0
# Out:
#    userid     name       msg
# 0       1  vinayak       NaN
# 1       2   mayank       NaN
# 2       3  aravind       NaN
# 0       1      NaN       hmm
# 1       1      NaN       ohk
# 2       2      NaN      haha
# 3       4      NaN  thik hai

# %%
pd.concat([users,msgs],axis=1)
# Out:
#    userid     name  userid       msg
# 0     1.0  vinayak       1       hmm
# 1     2.0   mayank       1       ohk
# 2     3.0  aravind       2      haha
# 3     NaN      NaN       4  thik hai

# %%
type(np.nan)
# Out:
# float

# %% [markdown]
# #merging (joins)
#
# <img src="https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/065/710/original/joins.webp?1708409218">

# %%
users
# Out:
#    userid     name
# 0       1  vinayak
# 1       2   mayank
# 2       3  aravind

# %%
msgs
# Out:
#    userid       msg
# 0       1       hmm
# 1       1       ohk
# 2       2      haha
# 3       4  thik hai

# %%
users.merge(msgs) #default join - inner
# Out:
#    userid     name   msg
# 0       1  vinayak   hmm
# 1       1  vinayak   ohk
# 2       2   mayank  haha

# %%
users.merge(msgs,on='userid')
# Out:
#    userid     name   msg
# 0       1  vinayak   hmm
# 1       1  vinayak   ohk
# 2       2   mayank  haha

# %%
users.merge(msgs,on='userid',how = 'inner')
# Out:
#    userid     name   msg
# 0       1  vinayak   hmm
# 1       1  vinayak   ohk
# 2       2   mayank  haha

# %%
users.merge(msgs,on='userid',how = 'left')
# Out:
#    userid     name   msg
# 0       1  vinayak   hmm
# 1       1  vinayak   ohk
# 2       2   mayank  haha
# 3       3  aravind   NaN

# %%
users.merge(msgs,on='userid',how = 'right')
# Out:
#    userid     name       msg
# 0       1  vinayak       hmm
# 1       1  vinayak       ohk
# 2       2   mayank      haha
# 3       4      NaN  thik hai

# %%
users.merge(msgs,on='userid',how = 'outer')
# Out:
#    userid     name       msg
# 0       1  vinayak       hmm
# 1       1  vinayak       ohk
# 2       2   mayank      haha
# 3       3  aravind       NaN
# 4       4      NaN  thik hai

# %%
users.rename(columns = {'userid':'id'},inplace=True)

# %%
users
# Out:
#    id     name
# 0   1  vinayak
# 1   2   mayank
# 2   3  aravind

# %%
msgs
# Out:
#    userid       msg
# 0       1       hmm
# 1       1       ohk
# 2       2      haha
# 3       4  thik hai

# %%
users.merge(msgs,left_on = 'id',right_on = 'userid',how = 'left' )
# Out:
#    id     name  userid   msg
# 0   1  vinayak     1.0   hmm
# 1   1  vinayak     1.0   ohk
# 2   2   mayank     2.0  haha
# 3   3  aravind     NaN   NaN

# %%
#imdb datasets
# !gdown 1s2TkjSpzNc4SyxqRrQleZyDIHlc7bxnd
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1s2TkjSpzNc4SyxqRrQleZyDIHlc7bxnd
# To: /content/movies.csv
# 100% 112k/112k [00:00<00:00, 3.77MB/s]

# %%
# !gdown 1Ws-_s1fHZ9nHfGLVUQurbHDvStePlEJm
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Ws-_s1fHZ9nHfGLVUQurbHDvStePlEJm
# To: /content/directors.csv
# 100% 65.4k/65.4k [00:00<00:00, 4.19MB/s]

# %%
#loading these files using pandas
movies = pd.read_csv('movies.csv',index_col = 0)
directors = pd.read_csv('directors.csv',index_col = 0)

# %%
movies.head()
# Out:
#       id     budget  popularity     revenue  \
# 0  43597  237000000         150  2787965087
# 1  43598  300000000         139   961000000
# 2  43599  245000000         107   880674609
# 3  43600  250000000         112  1084939099
# 5  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 5                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day
# 0         4762  2009   Dec  Thursday
# 1         4763  2007   May  Saturday
# 2         4764  2015   Oct    Monday
# 3         4765  2012   Jul    Monday
# 5         4767  2007   May   Tuesday

# %%
directors.head()
# Out:
#        director_name    id gender
# 0      James Cameron  4762   Male
# 1     Gore Verbinski  4763   Male
# 2         Sam Mendes  4764   Male
# 3  Christopher Nolan  4765   Male
# 4     Andrew Stanton  4766   Male

# %%
#rows and cols
movies.shape
# Out:
# (1465, 11)

# %%
directors.shape
# Out:
# (2349, 3)

# %%
movies.head()
# Out:
#       id     budget  popularity     revenue  \
# 0  43597  237000000         150  2787965087
# 1  43598  300000000         139   961000000
# 2  43599  245000000         107   880674609
# 3  43600  250000000         112  1084939099
# 5  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 5                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day
# 0         4762  2009   Dec  Thursday
# 1         4763  2007   May  Saturday
# 2         4764  2015   Oct    Monday
# 3         4765  2012   Jul    Monday
# 5         4767  2007   May   Tuesday

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1465 entries, 0 to 4768
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            1465 non-null   int64
#  1   budget        1465 non-null   int64
#  2   popularity    1465 non-null   int64
#  3   revenue       1465 non-null   int64
#  4   title         1465 non-null   object
#  5   vote_average  1465 non-null   float64
#  6   vote_count    1465 non-null   int64
#  7   director_id   1465 non-null   int64
#  8   year          1465 non-null   int64
#  9   month         1465 non-null   object
#  10  day           1465 non-null   object
# dtypes: float64(1), int64(7), object(3)
# memory usage: 137.3+ KB

# %%
directors.head()
# Out:
#        director_name    id gender
# 0      James Cameron  4762   Male
# 1     Gore Verbinski  4763   Male
# 2         Sam Mendes  4764   Male
# 3  Christopher Nolan  4765   Male
# 4     Andrew Stanton  4766   Male

# %%
directors['id'].nunique()
# Out:
# 2349

# %%
movies['director_id'].unique()
# Out:
# array([4762, 4763, 4764, 4765, 4767, 4771, 4772, 4773, 4774, 4775, 4776,
#        4777, 4779, 4780, 4782, 4785, 4786, 4788, 4791, 4793, 4794, 4797,
#        4798, 4799, 4802, 4803, 4804, 4805, 4808, 4809, 4810, 4811, 4812,
#        4813, 4814, 4829, 4831, 4832, 4833, 4838, 4839, 4842, 4845, 4846,
#        4847, 4849, 4854, 4857, 4858, 4859, 4863, 4865, 4866, 4867, 4868,
#        4872, 4873, 4874, 4876, 4880, 4881, 4885, 4886, 4888, 4889, 4890,
#        4892, 4893, 4894, 4900, 4904, 4909, 4913, 4915, 4917, 4918, 4921,
#        4923, 4924, 4925, 4926, 4927, 4930, 4935, 4936, 4945, 4947, 4948,
#        4949, 4955, 4958, 4960, 4964, 4965, 4967, 4974, 4978, 4989, 4991,
#        4993, 4995, 4998, 5002, 5005, 5008, 5009, 5014, 5017, 5024, 5031,
#        5033, 5034, 5035, 5037, 5039, 5047, 5053, 5056, 5059, 5061, 5067,
#        5082, 5087, 5088, 5093, 5096, 5097, 5101, 5105, 5111, 5113, 5115,
#        5116, 5123, 5125, 5130, 5132, 5135, 5140, 5147, 5148, 5152, 5157,
# ...

# %%
movies['director_id'].nunique()
# Out:
# 199

# %%
'ram' in 'rammohan'
# Out:
# True

# %%
movies['director_id'].isin(directors['id'])
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 5       True
#         ...
# 4736    True
# 4743    True
# 4748    True
# 4749    True
# 4768    True
# Name: director_id, Length: 1465, dtype: bool

# %%
np.all(movies['director_id'].isin(directors['id']))
# Out:
# np.True_

# %%
movies['director_id'].isin(directors['id']).all()
# Out:
# np.True_

# %%
#merging
data = pd.merge(movies,directors,left_on = 'director_id',right_on = 'id',how = 'left')

# %%
data.head()
# Out:
#     id_x     budget  popularity     revenue  \
# 0  43597  237000000         150  2787965087
# 1  43598  300000000         139   961000000
# 2  43599  245000000         107   880674609
# 3  43600  250000000         112  1084939099
# 4  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day      director_name  id_y gender
# 0         4762  2009   Dec  Thursday      James Cameron  4762   Male
# 1         4763  2007   May  Saturday     Gore Verbinski  4763   Male
# ...

# %%
data.drop(columns = ['id_y','director_id'],inplace=True)

# %%
data
# Out:
#        id_x     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1460  48363          0           3      321952
# 1461  48370      27000          19     3151130
# 1462  48375          0           7           0
# 1463  48376          0           3           0
# 1464  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
#quiz
#How to filter those records where movies are released either in the year 2015, 2016 or 2012 from the movies dataset?

# %%
#apply() => is used apply a function along an axis of the dataframe/series

# %%
def encode(data):
  if data == 'Male':
    return 0
  else:
    return 1

# %%
data['gender'] = data['gender'].apply(encode)

# %%
data
# Out:
#        id_x     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1460  48363          0           3      321952
# 1461  48370      27000          19     3151130
# 1462  48375          0           7           0
# 1463  48376          0           3           0
# 1464  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
data[['revenue','budget']].head()
# Out:
#       revenue     budget
# 0  2787965087  237000000
# 1   961000000  300000000
# 2   880674609  245000000
# 3  1084939099  250000000
# 4   890871626  258000000

# %%
def prof(x):
  return x['revenue']-x['budget']

# %%
data['profit'] = data[['revenue','budget']].apply(prof,axis=1) #defult axis = 0
data
# Out:
#        id_x     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1460  48363          0           3      321952
# 1461  48370      27000          19     3151130
# 1462  48375          0           7           0
# 1463  48376          0           3           0
# 1464  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
data['profit'] = data[['revenue','budget']].apply(prof) #defult axis = 0
data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-74-0b29351c2311> in <cell line: 0>()
# ----> 1 data['profit'] = data[['revenue','budget']].apply(prof)
#       2 data
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10372             kwargs=kwargs,
#   10373         )
# > 10374         return op.apply().__finalize__(self, method="apply")
#   10375
#   10376     def map(
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/apply.py in apply(self)
#     914             return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
#     915
# --> 916         return self.apply_standard()
#     917
#     918     def agg(self):
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/apply.py in apply_standard(self)
# ...

# %%
data
# Out:
#        id_x     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1460  48363          0           3      321952
# 1461  48370      27000          19     3151130
# 1462  48375          0           7           0
# 1463  48376          0           3           0
# 1464  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
data.groupby('director_name')

# %%
data.groupby('director_name').ngroups
# Out:
# 199

# %%
data.groupby('director_name').groups
# Out:
# {'Adam McKay': [176, 323, 366, 505, 839, 916], 'Adam Shankman': [265, 300, 350, 404, 458, 843, 999, 1231], 'Alejandro González Iñárritu': [106, 749, 1015, 1034, 1077, 1405], 'Alex Proyas': [95, 159, 514, 671, 873], 'Alexander Payne': [793, 1006, 1101, 1211, 1281], 'Andrew Adamson': [11, 43, 328, 501, 947], 'Andrew Niccol': [533, 603, 701, 722, 1439], 'Andrzej Bartkowiak': [349, 549, 754, 911, 924], 'Andy Fickman': [517, 681, 909, 926, 973, 1023], 'Andy Tennant': [314, 320, 464, 593, 676, 885], 'Ang Lee': [99, 134, 748, 840, 1089, 1110, 1132, 1184], 'Anne Fletcher': [610, 650, 736, 789, 1206], 'Antoine Fuqua': [310, 338, 424, 467, 576, 808, 818, 1105], 'Atom Egoyan': [946, 1128, 1164, 1194, 1347, 1416], 'Barry Levinson': [313, 319, 471, 594, 878, 898, 1013, 1037, 1082, 1143, 1185, 1345, 1378], 'Barry Sonnenfeld': [13, 48, 90, 205, 591, 778, 783], 'Ben Stiller': [209, 212, 547, 562, 850], 'Bill Condon': [102, 307, 902, 1233, 1381], 'Bobby Farrelly': [352, 356, 481, 498, 624, 630, 654, 
# ...

# %%
data.groupby('director_name').get_group('Christopher Nolan')
# Out:
#        id_x     budget  popularity     revenue                  title  \
# 3     43600  250000000         112  1084939099  The Dark Knight Rises
# 45    43662  185000000         187  1004558444        The Dark Knight
# 58    43692  165000000         724   675120017           Interstellar
# 59    43693  160000000         167   825532764              Inception
# 74    43716  150000000         115   374218673          Batman Begins
# 565   44630   46000000          41   113714830               Insomnia
# 641   44793   40000000          74   109676311           The Prestige
# 1341  47170    9000000          60    39723096                Memento
#
#       vote_average  vote_count  year month        day      director_name  \
# 3              7.6        9106  2012   Jul     Monday  Christopher Nolan
# 45             8.2       12002  2008   Jul  Wednesday  Christopher Nolan
# 58             8.1       10867  2014   Nov  Wednesday  Christopher Nolan
# ...

# %%
data.groupby('director_name')['title'].count()
# Out:
# director_name
# Adam McKay                      6
# Adam Shankman                   8
# Alejandro González Iñárritu     6
# Alex Proyas                     5
# Alexander Payne                 5
#                                ..
# Wes Craven                     10
# Wolfgang Petersen               7
# Woody Allen                    18
# Zack Snyder                     7
# Zhang Yimou                     6
# Name: title, Length: 199, dtype: int64

# %% [markdown]
# <img src="https://learning.oreilly.com/api/v2/epubs/urn:orm:book:9781491912126/files/assets/pyds_03in01.png">

# %%
data.groupby('director_name')['year'].aggregate()['min','max','count']
# Out:
#                               min   max  count
# director_name
# Adam McKay                   2004  2015      6
# Adam Shankman                2001  2012      8
# Alejandro González Iñárritu  2000  2015      6
# Alex Proyas                  1994  2016      5
# Alexander Payne              1999  2013      5
# ...                           ...   ...    ...
# Wes Craven                   1984  2011     10
# Wolfgang Petersen            1981  2006      7
# Woody Allen                  1977  2013     18
# Zack Snyder                  2004  2016      7
# Zhang Yimou                  2002  2014      6
#
# [199 rows x 3 columns]

# %%
#Given a dataframe of employee rating info (emp_id, monthly_rating). How will you calculate the average rating of each employee?

# %%
df.groupby('emp_id')['monthly_rating'].mean()

# %%
#For each year, how you will get the average, lowest, and highest value of movie ratings?

# %%
data.groupby('year').aggregate({'vote_average': ['mean','min','max']})
# Out:
#      vote_average
#              mean  min  max
# year
# 1976     7.633333  7.2  8.0
# 1977     6.900000  6.1  7.8
# 1978     7.020000  5.9  7.9
# 1979     7.025000  5.6  8.0
# 1980     7.187500  6.4  7.9
# 1981     6.927273  6.0  7.9
# 1982     6.810000  5.5  7.9
# 1983     6.666667  4.5  8.0
# 1984     6.760000  6.1  7.3
# 1985     6.885714  5.9  8.0
# 1986     6.809091  5.8  7.8
# 1987     6.991667  6.1  7.6
# 1988     6.692308  5.7  7.6
# 1989     6.750000  5.5  7.6
# 1990     6.661111  5.8  8.2
# 1991     7.100000  6.6  8.1
# 1992     6.640909  5.7  8.0
# 1993     7.144444  6.1  8.3
# 1994     6.596774  5.0  8.3
# 1995     6.509091  4.5  8.1
# 1996     6.384783  5.4  7.8
# 1997     6.552174  4.1  7.9
# 1998     6.442222  4.9  7.9
# 1999     6.384375  5.1  8.3
# 2000     6.347458  4.4  8.1
# 2001     6.217742  3.7  8.0
# 2002     6.359420  3.4  8.0
# 2003     6.115517  4.4  8.1
# 2004     6.427869  4.7  7.7
# 2005     6.229577  3.1  7.7
# 2006     6.212329  3.6  8.0
# ...

# %%
data.groupby('year')['vote_average'].aggregate(['mean','min','max'])
# Out:
#           mean  min  max
# year
# 1976  7.633333  7.2  8.0
# 1977  6.900000  6.1  7.8
# 1978  7.020000  5.9  7.9
# 1979  7.025000  5.6  8.0
# 1980  7.187500  6.4  7.9
# 1981  6.927273  6.0  7.9
# 1982  6.810000  5.5  7.9
# 1983  6.666667  4.5  8.0
# 1984  6.760000  6.1  7.3
# 1985  6.885714  5.9  8.0
# 1986  6.809091  5.8  7.8
# 1987  6.991667  6.1  7.6
# 1988  6.692308  5.7  7.6
# 1989  6.750000  5.5  7.6
# 1990  6.661111  5.8  8.2
# 1991  7.100000  6.6  8.1
# 1992  6.640909  5.7  8.0
# 1993  7.144444  6.1  8.3
# 1994  6.596774  5.0  8.3
# 1995  6.509091  4.5  8.1
# 1996  6.384783  5.4  7.8
# 1997  6.552174  4.1  7.9
# 1998  6.442222  4.9  7.9
# 1999  6.384375  5.1  8.3
# 2000  6.347458  4.4  8.1
# 2001  6.217742  3.7  8.0
# 2002  6.359420  3.4  8.0
# 2003  6.115517  4.4  8.1
# 2004  6.427869  4.7  7.7
# 2005  6.229577  3.1  7.7
# 2006  6.212329  3.6  8.0
# 2007  6.307407  3.2  7.9
# 2008  6.268657  3.0  8.2
# 2009  6.190909  3.9  7.9
# 2010  6.223810  4.2  8.1
# ...

# %%
#group based filtering
#how to find out the details of the movies by high budget directors ?
#high budget directors:
 # atleast one movier with budget > 100M

# %%
data['budget'] > 100000000
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1460    False
# 1461    False
# 1462    False
# 1463    False
# 1464    False
# Name: budget, Length: 1465, dtype: bool

# %%
data[data['budget'] > 100000000]
# Out:
#       id_x     budget  popularity     revenue  \
# 0    43597  237000000         150  2787965087
# 1    43598  300000000         139   961000000
# 2    43599  245000000         107   880674609
# 3    43600  250000000         112  1084939099
# 4    43602  258000000         115   890871626
# ..     ...        ...         ...         ...
# 185  43897  105000000          58   121214377
# 186  43898  102000000          73   130482868
# 201  43929  115000000          41   274703340
# 290  44088  130000000          50   117831631
# 328  44162  150000000          47   919838758
#
#                                         title  vote_average  vote_count  year  \
# 0                                      Avatar           7.2       11800  2009
# 1    Pirates of the Caribbean: At World's End           6.9        4500  2007
# 2                                     Spectre           6.3        4466  2015
# 3                       The Dark Knight Rises           7.6        9106  2012
# ...

# %%
#continue in this next class

# %%
pd1 = pd.merge(movies, directors, left_on='director_id', right_on='id', how='left')
pd1
# Out:
#        id_x     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1460  48363          0           3      321952
# 1461  48370      27000          19     3151130
# 1462  48375          0           7           0
# 1463  48376          0           3           0
# 1464  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
pd2 = pd.merge(movies, directors, left_on='director_id', right_on='id', how='inner')
pd2
# Out:
#        id_x     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1460  48363          0           3      321952
# 1461  48370      27000          19     3151130
# 1462  48375          0           7           0
# 1463  48376          0           3           0
# 1464  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
pd1==pd2
# Out:
#       id_x  budget  popularity  revenue  title  vote_average  vote_count  \
# 0     True    True        True     True   True          True        True
# 1     True    True        True     True   True          True        True
# 2     True    True        True     True   True          True        True
# 3     True    True        True     True   True          True        True
# 4     True    True        True     True   True          True        True
# ...    ...     ...         ...      ...    ...           ...         ...
# 1460  True    True        True     True   True          True        True
# 1461  True    True        True     True   True          True        True
# 1462  True    True        True     True   True          True        True
# 1463  True    True        True     True   True          True        True
# 1464  True    True        True     True   True          True        True
#
#       director_id  year  month   day  director_name  id_y  gender
# ...
